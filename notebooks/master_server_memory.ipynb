# %%
import pathlib

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from use_devtools.parsers import parse_all_process_memories, parse_memory_overhead

# %%
RAW_DATA_DIR = pathlib.Path("../data/master-servers")

# %%
mem_data = parse_all_process_memories(RAW_DATA_DIR / "Mixed_WOrkloads", ["bpdbm"])

# %%
mem_df = pd.DataFrame.from_dict(mem_data, orient="index", columns=["bpdbm"])
mem_df["bpdbm"].max() // 1024 // 1024
# Out:
# 12

# %%
meminfo_data = parse_memory_overhead(RAW_DATA_DIR / "Mixed_WOrkloads")

# %%
meminfo_df = pd.DataFrame.from_dict(meminfo_data, orient="index", columns=["MemTotal", "MemFree", "Buffers", "Cached"])

# %%
(meminfo_df["MemTotal"] - meminfo_df["MemFree"]).min()
# Out:
# 23101320
